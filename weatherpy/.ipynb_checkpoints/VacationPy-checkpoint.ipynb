# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#Import cities file as DataFrame
cities_df = pd.read_csv("output_data/cities.csv")
cities_df.head()
# Out:
#    Unnamed: 0               City      Lat       Lng  Max Temp  Humidity  \
# 0           0  Saint Paul Harbor  57.7900 -152.4072     42.80        49
# 1           1            Rikitea -23.1203 -134.9692     79.48        63
# 2           2         Porto-Novo   6.4965    2.6036     78.80        61
# 3           3             Atuona  -9.8000 -139.0333     78.15        80
# 4           4           Katsuura  35.1333  140.3000     37.99       100
#
#    Cloudiness  Wind Speed Country        Date
# 0          40       10.36      US  1611444735
# 1           0        7.45      PF  1611444735
# 2         100        2.30      BJ  1611444735
# 3           6       18.37      PF  1611444735
# 4          75       20.71      JP  1611444735

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#configure gmaps
gmaps.configure(api_key = g_key)

# %%
#Store latitude and longitude in locations
locations = cities_df[["Lat", "Lng"]]

#Store humidity
humidity = cities_df['Humidity']

# %%
#Plot Heatmap
fig = gmaps.figure()

#Add Heatmap layer to map
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=10, 
                                 point_radius=1 )
#Add layer
fig.add_layer(heat_layer)

# Display figure
print(fig)
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
weather_df = cities_df[(cities_df['Max Temp'] > 70)]
weather_df = weather_df[(weather_df['Max Temp'] < 80)]
weather_df = weather_df[(weather_df['Wind Speed'] < 10)]
weather_df = weather_df[(weather_df['Cloudiness'] == 0)]


count = len(weather_df['Max Temp'])
print(count)

weather_df.head(10)
# Out:
# 5
#      Unnamed: 0                  City      Lat       Lng  Max Temp  Humidity  \
# 1             1               Rikitea -23.1203 -134.9692     79.48        63
# 60           60   Aguada de Pasajeros  22.3850  -80.8508     77.00        73
# 138         138  Makkah al Mukarramah  21.4267   39.8261     72.82        47
# 232         232               Le Port -20.9373   55.2919     75.20        73
# 380         380                Ulundi -28.3352   31.4162     70.57        90
#
#      Cloudiness  Wind Speed Country        Date
# 1             0        7.45      PF  1611444735
# 60            0        5.75      CU  1611444741
# 138           0        3.56      SA  1611444749
# 232           0        8.05      RE  1611444758
# 380           0        4.25      ZA  1611444774

# %%
###Gather the required information
#lat = list(weather_df['Lat']) #list of latitudes
#lng = list(weather_df['Lng']) #list of longitutdes
#Get the number of records (coordinates) to be created
#n = len(lat)

###Create the coordinates
#coordinates = [] #create an empty container to store the created coordinates
#create each coordinate one-by-one
#for i in range(n): #iterate by each index so we proccess each individual index
    #grab current latitude and longitude that I'm working with
#    lat0 = lat[i]
#    lng0 = lng[i]
    #create the coordinate
#    coordinate = f"{lat0}, {lng0}"
#    print(coordinate)
#    #store our calculated coordinate
#    coordinates.append(coordinate)
#    #coordinates += [coordinate,]

###Generate Requests
#set up parameters
#target_radius = 5000
#target_type = "lodging"
#base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#requestResults = [] #create an empty container to store the received requests
#for i in range(n):
    #tailor parameters for current request
#    params = {
#        "location": target_coordinates,
#        "radius":target_radius,
#        "type": target_type,
#        "key":g_key,
#    }
    #Gather the result of our specific request
#    requestResult = requests.get(base_url, params=params)
#    #store result of our specific request
#    requestResults.append(requestResult)

#requestResults #display results of requests

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
target_radius = 5000
target_type = "lodging"
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

coordinates = ['{}, {}'.format(lat, lng) for lat, lng in zip(weather_df['Lat'], weather_df['Lng'])]
p_requests = [requests.get(base_url, params={
    'location':coordinate,
    'radius':target_radius,
    'type':target_type,
    'key':g_key
}) for coordinate in coordinates]

print(p_requests)
# Out:
# [<Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>]

# %%
places_data = [place.json() for place in p_requests]
places_data
# Out:
# [{'html_attributions': [],
#   'results': [{'business_status': 'OPERATIONAL',
#     'geometry': {'location': {'lat': -23.1206197, 'lng': -134.9687529},
#      'viewport': {'northeast': {'lat': -23.1194598197085,
#        'lng': -134.9673886697085},
#       'southwest': {'lat': -23.1221577802915, 'lng': -134.9700866302915}}},
#     'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#     'name': "Pension Maro'i",
#     'opening_hours': {'open_now': True},
#     'photos': [{'height': 2304,
#       'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111098332724302207930">luigia b.</a>'],
#       'photo_reference': 'ATtYBwK1fA0L_TmVo-nLruMOmED7A6HfjFlke15HGJS5xJP_77q2FGseqirMWAsNmBzijmQfmAkm4R5cw_0TcloAyQmlU4MPj1YrlPRFuuUNAKX1pLGra1l57Byrr6YNxT5HjZx4rVG2zXyNCebSh1kvZukA2Zefdkf3vs07FQ0CFjjjPRSW',
#       'width': 4096}],
#     'place_id': 'ChIJnW6Jh0aIJ54RV2HnC1r0Hjw',
#     'plus_code': {'global_code': '5487V2HJ+QF'},
# ...

# %%
[place['results'][0] for place in places_data]

hotel_list = [h_attribute['results'][0]['name'] for h_attribute in places_data]
lat_list = [h_attribute['results'][0]['geometry']['location']['lat'] for h_attribute in places_data]
lng_list = [h_attribute['results'][0]['geometry']['location']['lng'] for h_attribute in places_data]
pid_list = [h_attribute['results'][0]['place_id'] for h_attribute in places_data]
lng_list


hotel_df = pd.DataFrame(data={'Hotel Name': hotel_list, 'Lat': lat_list, 'Lng': lng_list,'Place ID': pid_list }, copy=True)
hotel_df
# Out:
#                                    Hotel Name        Lat         Lng  \
# 0                              Pension Maro'i -23.120620 -134.968753
# 1                              Soles de Marti  22.384759  -80.849856
# 2  Makkah Clock Royal Tower, A Fairmont Hotel  21.418034   39.825569
# 3                                 Villa Maido -20.944511   55.289065
# 4                             Ekhethelo Lodge -28.329798   31.405409
#
#                       Place ID
# 0  ChIJnW6Jh0aIJ54RV2HnC1r0Hjw
# 1  ChIJr99kWx9V04gRLmjr-8uXTME
# 2  ChIJN1Hy6rcEwhURanDxKxvnCIM
# 3  ChIJdRjMW-yIgiERENETxGOc7zI
# 4  ChIJBYZpZ3Bj8B4RcQeg4-xiI5g

# %%
# Sample
target_radius = 5000
target_type = "lodging"
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

coordinates = ['{}, {}'.format(lat, lng) for lat, lng in zip(weather_df['Lat'], weather_df['Lng'])]
p_requests = [requests.get(base_url, params={
    'location':coordinate,
    'radius':target_radius,
    'type':target_type,
    'key':g_key
}) for coordinate in coordinates]

print(p_requests)

# %%
#Sample
places_data = [place.json() for place in p_requests]
places_data

# %%
#New
d_base_url = 'https://maps.googleapis.com/maps/api/place/details/json?'
a_c = 'address_component'

p_ids = [].format(place) for places in hotel_df['Place ID']]
d_requests = [requests.get(d_base_url, params={
    'place_id' : p_ids,
    'fields': a_c,
    'key':g_key
}) for p_id in p_ids]

print (d_requests)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-5eb64e65957f> in <module>
#       3 a_c = 'address_component'
#       4
# ----> 5 p_ids = [().format(place) for places in hotel_df['Place ID']]
#       6 d_requests = [requests.get(d_base_url, params={
#       7     'place_id' : p_ids,
#
# <ipython-input-60-5eb64e65957f> in <listcomp>(.0)
#       3 a_c = 'address_component'
#       4
# ----> 5 p_ids = [().format(place) for places in hotel_df['Place ID']]
#       6 d_requests = [requests.get(d_base_url, params={
#       7     'place_id' : p_ids,
#
# AttributeError: 'tuple' object has no attribute 'format'

# %%
#new

detail_data = [detail.json() for detail in d_requests]
detail_data
# Out:
# [{'html_attributions': [],
#   'result': {'address_components': [{'long_name': 'Rikitea',
#      'short_name': 'Rikitea',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Gambier',
#      'short_name': 'Gambier',
#      'types': ['locality', 'political']},
#     {'long_name': 'Gambier Islands',
#      'short_name': 'Gambier Islands',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'The Tuamotu and Gambier Islands',
#      'short_name': 'The Tuamotu and Gambier Islands',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'French Polynesia',
#      'short_name': 'PF',
#      'types': ['country', 'political']}]},
#   'status': 'OK'},
#  {'html_attributions': [],
#   'result': {'address_components': [{'long_name': 'Rikitea',
#      'short_name': 'Rikitea',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Gambier',
#      'short_name': 'Gambier',
# ...

# %%
itms = details_data['result']['address_components']
country = None
for itm in itms:
    if 'country' in itm['types']:
        country = itm['long_name']
        break
print(country)
# Out:
# French Polynesia

# %%
#Old
#https://maps.googleapis.com/maps/api/place/details/output?parameters

key = g_key
place = "ChIJnW6Jh0aIJ54RV2HnC1r0Hjw"

d_url = f'https://maps.googleapis.com/maps/api/place/details/json?place_id={place}&fields=address_component&key={g_key}'

d_requests = requests.get(d_url)

print(d_url)
print(d_requests)
# Out:
# https://maps.googleapis.com/maps/api/place/details/json?place_id=ChIJnW6Jh0aIJ54RV2HnC1r0Hjw&fields=address_component&key=AIzaSyCxUB8L7kVe56uuvE_3lXsCLE-TsoJX_Vo
# <Response [200]>
# AIzaSyCxUB8L7kVe56uuvE_3lXsCLE-TsoJX_Vo

# %%
#Old
#convert resonse to json
details_data = d_requests.json()

#print details_data 
print(json.dumps(details_data,indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "result": {
#         "address_components": [
#             {
#                 "long_name": "Rikitea",
#                 "short_name": "Rikitea",
#                 "types": [
#                     "neighborhood",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Gambier",
#                 "short_name": "Gambier",
#                 "types": [
#                     "locality",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "Gambier Islands",
#                 "short_name": "Gambier Islands",
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ]
#             },
#             {
#                 "long_name": "The Tuamotu and Gambier Islands",
#                 "short_name": "The Tuamotu and Gambier Islands",
# ...

# %%
itms = details_data['result']['address_components']
country = None
for itm in itms:
    if 'locality' in itm['types']:
        locality = itm['long_name']
        break
print(locality)
# Out:
# Gambier

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-464b2b3e63ad> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# <ipython-input-16-464b2b3e63ad> in <listcomp>(.0)
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# KeyError: 'City'

# %%
# Add marker layer ontop of heat map


# Display figure
