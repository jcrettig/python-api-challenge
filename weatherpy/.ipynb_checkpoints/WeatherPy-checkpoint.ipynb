# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import scipy.stats as st
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import requests
from sklearn import datasets

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
#len(cities)
cities
# Out:
# ['kodiak',
#  'rikitea',
#  'porto novo',
#  'atuona',
#  'katsuura',
#  'leningradskiy',
#  'bol',
#  'tuktoyaktuk',
#  'ponta delgada',
#  'kushima',
#  'arraial do cabo',
#  'khatanga',
#  'port lincoln',
#  'cayenne',
#  'airai',
#  'chokurdakh',
#  'mount isa',
#  'lebu',
#  'cape town',
#  'naftah',
#  'ushuaia',
#  'somanda',
#  'sitka',
#  'castro',
#  'bluff',
#  'sijunjung',
#  'busselton',
#  'tsihombe',
#  'saskylakh',
#  'punta arenas',
#  'monatele',
#  'orotukan',
#  'hermanus',
#  'gornopravdinsk',
#  'hithadhoo',
#  'pekan',
#  'poum',
#  'opuwo',
#  'mouzakion',
#  'hobart',
#  'waterloo',
#  'illoqqortoormiut',
#  'ponta do sol',
#  'izhma',
#  'torbay',
#  'mosquera',
#  'kapaa',
#  'kieta',
#  'la ronge',
#  'katherine',
#  'flinders',
#  'narrabri',
#  'luanda',
#  'shancheng',
#  'qaanaaq',
#  'port alfred',
#  'vestmannaeyjar',
#  'mollendo',
#  'longyearbyen',
#  'mayumba',
#  'tartus',
#  'mataura',
#  'seoul',
#  'asosa',
#  'bredasdorp',
#  'aguada de pasajeros',
#  'bambous virieux',
#  'broome',
#  'vaini',
#  'ribeira grande',
#  'ban nahin',
#  'trairi',
#  'saint george',
#  'east london',
#  'lakes entrance',
#  'tasiilaq',
#  'mar del plata',
#  'yulara',
#  'arman',
#  'butaritari',
#  'kushmurun',
#  'uyuni',
#  'gigmoto',
#  'tiksi',
#  'barentsburg',
#  'cidreira',
#  'rawannawi',
#  'miri',
#  'mogadouro',
#  'saint anthony',
#  'victoria',
#  'pevek',
#  'isangel',
#  'provideniya',
#  'lahaina',
#  'warqla',
#  'jiuquan',
#  'taolanaro',
#  'sungaipenuh',
#  'faanui',
#  'maragogi',
#  'bua yai',
#  'merauke',
#  'puerto escondido',
#  'caravelas',
#  'kavieng',
#  'saint-augustin',
#  'jamestown',
#  'yanan',
#  'takoradi',
#  'barra dos coqueiros',
#  'louisbourg',
#  'baberu',
#  'grand river south east',
#  'ilulissat',
#  'ipeti',
#  'vapnyarka',
#  'taunggyi',
#  'hilo',
#  'iqaluit',
#  'bandar-e lengeh',
#  'bucerias',
#  'avarua',
#  'wagar',
#  'kahului',
#  'yenagoa',
#  'lieksa',
#  'dikson',
#  'armizonskoye',
#  'tundla',
#  'bolshegrivskoye',
#  'los llanos de aridane',
#  'coos bay',
#  'touros',
#  'sorland',
#  'coquimbo',
#  'kaitangata',
#  'fortuna',
#  'lompoc',
#  'nelson bay',
#  'agucadoura',
#  'komsomolskiy',
#  'puerto del rosario',
#  'tuatapere',
#  'sonoita',
#  'smithers',
#  'mahebourg',
#  'najran',
#  'bosaso',
#  'karoi',
#  'new norfolk',
#  'tadine',
#  'rungata',
#  'mecca',
#  'viedma',
#  'kyzyl-suu',
#  'klaksvik',
#  'sao filipe',
#  'albany',
#  'te anau',
#  'athabasca',
#  'upernavik',
#  'puerto ayora',
#  'meyungs',
#  'tumannyy',
#  'lahij',
#  'tecoanapa',
#  'yinchuan',
#  'bushehr',
#  'nikolskoye',
#  'sinkat',
#  'geraldton',
#  'cabo san lucas',
#  'vao',
#  'esperance',
#  'karauzyak',
#  'balkhash',
#  'hambantota',
#  'norman wells',
#  'raga',
#  'morgan city',
#  'dese',
#  'cabatuan',
#  'khani',
#  'lata',
#  'kita',
#  'kapoeta',
#  'ngukurr',
#  'saldanha',
#  'yellowknife',
#  'elbrus',
#  'gorom-gorom',
#  'bitung',
#  'husavik',
#  'adrar',
#  'hobyo',
#  'yatou',
#  'vichuga',
#  'plettenberg bay',
#  'garoua',
#  'nanortalik',
#  'severo-kurilsk',
#  'georgetown',
#  'pangkalanbuun',
#  'mys shmidta',
#  'hinjilikatu',
#  'galle',
#  'guarapari',
#  'port elizabeth',
#  'araouane',
#  'arroyos y esteros',
#  'monywa',
#  'alyangula',
#  'palu',
#  'bengkulu',
#  'tilichiki',
#  'vitre',
#  'arlit',
#  'maymyo',
#  'cah ab',
#  'svetlyy',
#  'cap malheureux',
#  'ust-kamchatsk',
#  'ambilobe',
#  'savannah bight',
#  'jardim',
#  'itarema',
#  'naze',
#  'alugan',
#  'ancud',
#  'andover',
#  'petropavlovsk-kamchatskiy',
#  'ontario',
#  'vitim',
#  'buraydah',
#  'sorong',
#  'vangaindrano',
#  'korla',
#  'alghero',
#  'sheltozero',
#  'port hedland',
#  'kungurtug',
#  'turukhansk',
#  'riyadh',
#  'jalu',
#  'westport',
#  'prince albert',
#  'tautira',
#  'lupiro',
#  'dicabisagan',
#  'taoudenni',
#  'makaha',
#  'nazarovo',
#  'nam som',
#  'berlevag',
#  'le port',
#  'lovozero',
#  'nemuro',
#  'tura',
#  'el balyana',
#  'bethel',
#  'okha',
#  'marawi',
#  'carnarvon',
#  'namatanai',
#  'antalaha',
#  'clyde river',
#  'vestbygda',
#  'marathon',
#  'saint-philippe',
#  'khash',
#  'souillac',
#  'aswan',
#  'waw',
#  'cherskiy',
#  'kruisfontein',
#  'indramayu',
#  'solovetskiy',
#  'hyeres',
#  'saint-pierre',
#  'kangshan',
#  'byron bay',
#  'shakhtinsk',
#  'lagos',
#  'saryshagan',
#  'tabiauea',
#  'abonnema',
#  'boyabat',
#  'kurilsk',
#  'vinh',
#  'laguna',
#  'alofi',
#  'kharhial',
#  'salalah',
#  'pisco',
#  'barrow',
#  'kailahun',
#  'bagdarin',
#  'dubbo',
#  'batsfjord',
#  'jaca',
#  'rognan',
#  'finschhafen',
#  'amderma',
#  'hasaki',
#  'sesheke',
#  'novyy urgal',
#  'vila franca do campo',
#  'ferkessedougou',
#  'kabansk',
#  'chuy',
#  'puri',
#  'aflu',
#  'nioro',
#  'shangrao',
#  'basco',
#  'gat',
#  'sisimiut',
#  'beringovskiy',
#  'desa',
#  'ronneby',
#  'henties bay',
#  'bandiagara',
#  'kattivakkam',
#  'panzhihua',
#  'balimo',
#  'san jose',
#  'ustupo',
#  'richmond',
#  'bayan',
#  'mugur-aksy',
#  'naron',
#  'talnakh',
#  'guerrero negro',
#  'salinas',
#  'salisbury',
#  'sulecin',
#  'carauari',
#  'port hardy',
#  'nishihara',
#  'vaitape',
#  'kichera',
#  'kendari',
#  'yerbogachen',
#  'kavaratti',
#  'caranavi',
#  'totness',
#  'ridgeland',
#  'mizdah',
#  'palabuhanratu',
#  'belushya guba',
#  'tual',
#  'mahon',
#  'pacora',
#  'dalian',
#  'elizabeth city',
#  'vardo',
#  'solnechnyy',
#  'susangerd',
#  'imbituba',
#  'khandbari',
#  'swan hill',
#  'aalestrup',
#  'yumen',
#  'sentyabrskiy',
#  'aklavik',
#  'lorengau',
#  'bilibino',
#  'mangrol',
#  'weinan',
#  'bathurst',
#  'portland',
#  'knysna',
#  'taicheng',
#  'mumford',
#  'escanaba',
#  'avera',
#  'abakaliki',
#  'diapaga',
#  'cockburn town',
#  'vanimo',
#  'seymchan',
#  'hovd',
#  'sao joao da barra',
#  'nouadhibou',
#  'thompson',
#  'emba',
#  'san ramon',
#  'bertoua',
#  'chernyshevskiy',
#  'novoanninskiy',
#  'tefe',
#  'nabire',
#  'lavrentiya',
#  'falealupo',
#  'sahrak',
#  'tanda',
#  'horki',
#  'homei',
#  'hinton',
#  'verkhoyansk',
#  'toliary',
#  'petropavlovka',
#  'bayanday',
#  'gimli',
#  'longonjo',
#  'cauquenes',
#  'akyab',
#  'marcona',
#  'vaitupu',
#  'sao gabriel da cachoeira',
#  'waitati',
#  'kediri',
#  'karla',
#  'bulgan',
#  'doha',
#  'khandyga',
#  'samusu',
#  'egvekinot',
#  'diego de almagro',
#  'hay river',
#  'harper',
#  'ulundi',
#  'saint-georges',
#  'praia da vitoria',
#  'preobrazheniye',
#  'alice springs',
#  'casino',
#  'lezajsk',
#  'tupik',
#  'hervey bay',
#  'sioux lookout',
#  'inirida',
#  'north myrtle beach',
#  'grindavik',
#  'pitimbu',
#  'anastacio',
#  'sao sebastiao',
#  'okato',
#  'ketegyhaza',
#  'namibe',
#  'cuamba',
#  'abu kamal',
#  'diffa',
#  'honningsvag',
#  'emerald',
#  'kadoshkino',
#  'bonavista',
#  'colares',
#  'ulladulla',
#  'dengzhou',
#  'margate',
#  'qandahar',
#  'black river',
#  'taksimo',
#  'brownsville',
#  'kachug',
#  'karolinka',
#  'witu',
#  'ati',
#  'shingu',
#  'bubaque',
#  'bara',
#  'sayyan',
#  'ahlat',
#  'jaramana',
#  'coruripe',
#  'utiroa',
#  'labuhan',
#  'lensk',
#  'mayo',
#  'carutapera',
#  'saleaula',
#  'aranos',
#  'shorapani',
#  'walvis bay',
#  'brae',
#  'catamarca',
#  'neiafu',
#  'roma',
#  'elko',
#  'lasa',
#  'rawson',
#  'tessalit',
#  'oum hadjer',
#  'gromiljak',
#  'codrington',
#  'hamilton',
#  'lagoa',
#  'garavuti',
#  'jerez',
#  'koutiala',
#  'kwinana',
#  'velykyy klyuchiv',
#  'san roque',
#  'attawapiskat',
#  'dingle',
#  'fukuma',
#  'oruro',
#  'mergui',
#  'luderitz',
#  'the valley',
#  'kuche',
#  'narsaq',
#  'townsville',
#  'uribia',
#  'ketou',
#  'praia',
#  'dzilam gonzalez',
#  'mustasaari',
#  'panaba',
#  'arys',
#  'skalistyy',
#  'biak',
#  'san patricio',
#  'el faiyum',
#  'deputatskiy',
#  'chkalovsk',
#  'manzhouli',
#  'bolungarvik',
#  'anloga',
#  'ust-nera',
#  'evensk',
#  'kataysk',
#  'nizhneyansk',
#  'sao miguel do araguaia',
#  'ouallam',
#  'whitehorse',
#  'basoko',
#  'sataua',
#  'macau',
#  'road town',
#  'coahuayana',
#  'savonlinna',
#  'moyale',
#  'trinidad',
#  'joshimath',
#  'do gonbadan',
#  'orlik',
#  'khor',
#  'puerto madero',
#  'arona',
#  'san felipe',
#  'auki',
#  'savinka',
#  'baruun-urt',
#  'sechura',
#  'hue',
#  'sosnovo-ozerskoye',
#  'luwero',
#  'kimbe',
#  'manggar',
#  'kalabo',
#  'bichura',
#  'batagay-alyta',
#  'aasiaat',
#  'launceston',
#  'mwinilunga',
#  'truro',
#  'celestun',
#  'nalut',
#  'strezhevoy',
#  'kargala',
#  'bathsheba',
#  'zhigansk',
#  'san cristobal',
#  'tazovskiy',
#  'yar-sale',
#  'mae hong son',
#  'oltu',
#  'lishui',
#  'xining',
#  'kirakira',
#  'daru',
#  'marsa matruh',
#  'champerico',
#  'anar darreh',
#  'boende',
#  'bumba',
#  'lolua',
#  'shenzhen',
#  'juneau',
#  'piacabucu',
#  'rumphi',
#  'saint-joseph',
#  'thio',
#  'kempele',
#  'kihei',
#  'rocha',
#  'anzoategui',
#  'karratha',
#  'brookhaven',
#  'hammerfest',
#  'tokzar',
#  'grand gaube',
#  'yzeure',
#  'buckeye',
#  'hualmay',
#  'aitape',
#  'barabai',
#  'halifax',
#  'khonuu',
#  'yatsuo',
#  'severobaykalsk',
#  'kamaishi',
#  'teguise',
#  'bereznik',
#  'chocope',
#  'mount gambier',
#  'calvinia',
#  'atasu',
#  'bayir',
#  'doctor pedro p. pena',
#  'bargal',
#  'pabrade',
#  'asau',
#  'matara',
#  'kajaani',
#  'rochester']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#save configuration information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

#Build parital query
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
#Pull data to list to minimize pulls from API
responses = {city : requests.get(query_url + city).json() for city in cities}

# %%
#number of rows in list
len(responses)
# Out:
# 619

# %%
#set up lists to hold response info

xcity = []
Lat = []
Lng = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_Speed = []
Country = []
Date = []
record = 0
xset = 1

#print log header
print('Beginning Data Retrieval')     
print('-----------------------------')

#loop through cities and request data for each city
for city in cities:
    response = responses[city]
    
    #try to request info for city, if city is in API request the following data
    try:   
        xcity.append(response['name'])
        Lat.append(response['coord']['lat']) 
        Lng.append(response['coord']['lon'])
        Max_Temp.append(response['main']['temp_max'])
        Humidity.append(response['main']['humidity'])
        Cloudiness.append(response['clouds']['all'])
        Wind_Speed.append(response['wind']['speed'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        record = record + 1
        xset = 1
        print(f"Processing Record {record} of Set {xset} | {city})")
                      
              
    #handle exceptions for cities that are not available on the API
    except KeyError:
        print('City not found. Skipping...')
    except IndexError:
        print('City not found. Skipping...')



#print log footer
print('-----------------------------')                
print('Data Retrieval Complete')     
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak)
# Processing Record 2 of Set 1 | rikitea)
# Processing Record 3 of Set 1 | porto novo)
# Processing Record 4 of Set 1 | atuona)
# Processing Record 5 of Set 1 | katsuura)
# Processing Record 6 of Set 1 | leningradskiy)
# Processing Record 7 of Set 1 | bol)
# Processing Record 8 of Set 1 | tuktoyaktuk)
# Processing Record 9 of Set 1 | ponta delgada)
# Processing Record 10 of Set 1 | kushima)
# Processing Record 11 of Set 1 | arraial do cabo)
# Processing Record 12 of Set 1 | khatanga)
# Processing Record 13 of Set 1 | port lincoln)
# Processing Record 14 of Set 1 | cayenne)
# Processing Record 15 of Set 1 | airai)
# Processing Record 16 of Set 1 | chokurdakh)
# Processing Record 17 of Set 1 | mount isa)
# Processing Record 18 of Set 1 | lebu)
# Processing Record 19 of Set 1 | cape town)
# City not found. Skipping...
# Processing Record 20 of Set 1 | ushuaia)
# Processing Record 21 of Set 1 | somanda)
# Processing Record 22 of Set 1 | sitka)
# Processing Record 23 of Set 1 | castro)
# Processing Record 24 of Set 1 | bluff)
# Processing Record 25 of Set 1 | sijunjung)
# Processing Record 26 of Set 1 | busselton)
# City not found. Skipping...
# Processing Record 27 of Set 1 | saskylakh)
# Processing Record 28 of Set 1 | punta arenas)
# City not found. Skipping...
# Processing Record 29 of Set 1 | orotukan)
# Processing Record 30 of Set 1 | hermanus)
# Processing Record 31 of Set 1 | gornopravdinsk)
# Processing Record 32 of Set 1 | hithadhoo)
# Processing Record 33 of Set 1 | pekan)
# Processing Record 34 of Set 1 | poum)
# Processing Record 35 of Set 1 | opuwo)
# City not found. Skipping...
# Processing Record 36 of Set 1 | hobart)
# Processing Record 37 of Set 1 | waterloo)
# City not found. Skipping...
# Processing Record 38 of Set 1 | ponta do sol)
# Processing Record 39 of Set 1 | izhma)
# Processing Record 40 of Set 1 | torbay)
# Processing Record 41 of Set 1 | mosquera)
# Processing Record 42 of Set 1 | kapaa)
# Processing Record 43 of Set 1 | kieta)
# Processing Record 44 of Set 1 | la ronge)
# Processing Record 45 of Set 1 | katherine)
# Processing Record 46 of Set 1 | flinders)
# Processing Record 47 of Set 1 | narrabri)
# Processing Record 48 of Set 1 | luanda)
# Processing Record 49 of Set 1 | shancheng)
# Processing Record 50 of Set 1 | qaanaaq)
# Processing Record 51 of Set 1 | port alfred)
# Processing Record 52 of Set 1 | vestmannaeyjar)
# Processing Record 53 of Set 1 | mollendo)
# Processing Record 54 of Set 1 | longyearbyen)
# Processing Record 55 of Set 1 | mayumba)
# Processing Record 513 of Set 1 | tazovskiy)
# Processing Record 514 of Set 1 | yar-sale)
# Processing Record 515 of Set 1 | mae hong son)
# Processing Record 516 of Set 1 | oltu)
# Processing Record 517 of Set 1 | lishui)
# Processing Record 518 of Set 1 | xining)
# Processing Record 519 of Set 1 | kirakira)
# Processing Record 520 of Set 1 | daru)
# Processing Record 521 of Set 1 | marsa matruh)
# Processing Record 522 of Set 1 | champerico)
# City not found. Skipping...
# Processing Record 523 of Set 1 | boende)
# Processing Record 524 of Set 1 | bumba)
# City not found. Skipping...
# Processing Record 525 of Set 1 | shenzhen)
# Processing Record 526 of Set 1 | juneau)
# Processing Record 527 of Set 1 | piacabucu)
# Processing Record 528 of Set 1 | rumphi)
# Processing Record 529 of Set 1 | saint-joseph)
# Processing Record 530 of Set 1 | thio)
# Processing Record 531 of Set 1 | kempele)
# Processing Record 532 of Set 1 | kihei)
# Processing Record 533 of Set 1 | rocha)
# Processing Record 534 of Set 1 | anzoategui)
# Processing Record 535 of Set 1 | karratha)
# Processing Record 536 of Set 1 | brookhaven)
# Processing Record 537 of Set 1 | hammerfest)
# City not found. Skipping...
# Processing Record 538 of Set 1 | grand gaube)
# Processing Record 539 of Set 1 | yzeure)
# Processing Record 540 of Set 1 | buckeye)
# Processing Record 541 of Set 1 | hualmay)
# Processing Record 542 of Set 1 | aitape)
# Processing Record 543 of Set 1 | barabai)
# Processing Record 544 of Set 1 | halifax)
# City not found. Skipping...
# Processing Record 545 of Set 1 | yatsuo)
# Processing Record 546 of Set 1 | severobaykalsk)
# Processing Record 547 of Set 1 | kamaishi)
# Processing Record 548 of Set 1 | teguise)
# Processing Record 549 of Set 1 | bereznik)
# Processing Record 550 of Set 1 | chocope)
# Processing Record 551 of Set 1 | mount gambier)
# Processing Record 552 of Set 1 | calvinia)
# Processing Record 553 of Set 1 | atasu)
# Processing Record 554 of Set 1 | bayir)
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 555 of Set 1 | pabrade)
# Processing Record 556 of Set 1 | asau)
# Processing Record 557 of Set 1 | matara)
# Processing Record 558 of Set 1 | kajaani)
# Processing Record 559 of Set 1 | rochester)
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(xcity)
# Out:
# 559

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create data frame     
city_df = pd.DataFrame({
    'City' : xcity,
    'Lat' : Lat,
    'Lng' : Lng,
    'Max Temp' : Max_Temp,
    'Humidity' : Humidity,
    'Cloudiness' : Cloudiness,
    'Wind Speed' : Wind_Speed,
    'Country' : Country,
    'Date' : Date   
})

city_df.to_csv(output_data_file)

city_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Saint Paul Harbor  57.7900 -152.4072     42.80        49          40
# 1              Rikitea -23.1203 -134.9692     79.48        63           0
# 2           Porto-Novo   6.4965    2.6036     78.80        61         100
# 3               Atuona  -9.8000 -139.0333     78.15        80           6
# 4             Katsuura  35.1333  140.3000     37.99       100          75
# ..                 ...      ...       ...       ...       ...         ...
# 554            Pabradė  55.0000   25.7833     39.99        87           0
# 555               Asău  46.4333   26.4000     37.00        64          91
# 556             Matara   5.9485   80.5353     71.78        90          15
# 557            Kajaani  64.2273   27.7285     33.80        93          90
# 558          Rochester  43.1548  -77.6156     23.00        86          90
#
#      Wind Speed Country        Date
# 0         10.36      US  1611444735
# 1          7.45      PF  1611444735
# 2          2.30      BJ  1611444735
# 3         18.37      PF  1611444735
# 4         20.71      JP  1611444735
# ..          ...     ...         ...
# 554        9.22      LT  1611444793
# 555        3.58      RO  1611444793
# 556        7.81      LK  1611444793
# 557       10.36      FI  1611444793
# 558       10.36      US  1611444204
#
# [559 rows x 9 columns]

# %%
#Describe data in city_df
city_df.describe()
# Out:
#               Lat        Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  559.000000  559.00000  559.000000  559.000000  559.000000  559.000000
# mean    19.879673   25.82983   49.026458   73.590340   55.799642    7.911825
# std     32.481674   90.06869   33.589887   19.165624   39.067343    6.145262
# min    -54.800000 -179.16670  -55.010000    8.000000    0.000000    0.270000
# 25%     -5.611800  -52.53235   29.515000   64.000000   15.000000    3.240000
# 50%     21.283300   27.72850   62.600000   78.000000   72.000000    6.870000
# 75%     47.255300  108.13875   75.990000   87.000000   92.000000   10.360000
# max     78.218600  179.31670   98.580000  100.000000  100.000000   32.590000
#
#                Date
# count  5.590000e+02
# mean   1.611445e+09
# std    6.003911e+01
# min    1.611444e+09
# 25%    1.611445e+09
# 50%    1.611445e+09
# 75%    1.611445e+09
# max    1.611445e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#drop rows with Humidity > 100%
# not rows with Humidity > 100%

#  Get the indices of cities that have humidity over 100%.
# no cities > 100%

# %%
#Compute humidity outliers
quartiles = city_df['Humidity'].quantile([.25, .5, .75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq - lowerq
lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f'lowerq = {lowerq}')
print(f'upperq = {upperq}')
print(f'iqr = {iqr}')
print(f'lower_bound = {lower_bound}')
print(f'upper_bound = {upper_bound}')
# Out:
# lowerq = 64.0
# upperq = 87.0
# iqr = 23.0
# lower_bound = 29.5
# upper_bound = 121.5

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
#note: did not filter on upper bound since max is <
clean_city_df = city_df[city_df['Humidity'] > lower_bound].copy()
clean_city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  537.000000  537.000000  537.000000  537.000000  537.000000  537.000000
# mean    20.094089   26.611275   48.326834   75.759777   56.605214    7.890633
# std     33.001145   91.529455   33.995366   16.178690   39.017799    6.222821
# min    -54.800000 -179.166700  -55.010000   30.000000    0.000000    0.270000
# 25%     -6.884400  -53.673500   27.480000   67.000000   19.000000    3.180000
# 50%     22.285500   30.786100   61.110000   80.000000   75.000000    6.690000
# 75%     48.534800  110.099700   76.480000   88.000000   93.000000   10.360000
# max     78.218600  179.316700   89.600000  100.000000  100.000000   32.590000
#
#                Date
# count  5.370000e+02
# mean   1.611445e+09
# std    6.110876e+01
# min    1.611444e+09
# 25%    1.611445e+09
# 50%    1.611445e+09
# 75%    1.611445e+09
# max    1.611445e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Chart Inputs
lat = clean_city_df['Lat']
lng = clean_city_df['Lng']
max_temp = clean_city_df['Max Temp']
humidity = clean_city_df['Humidity']
cloudiness = clean_city_df['Cloudiness']
wind_speed = clean_city_df['Wind Speed']

# %%
#build scatter plot
x_values1 = lat
y_values1 = max_temp
plt.scatter(x_values1,y_values1)

#graph properties
plt.title('City Latitude vs. Max Temperature')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
#plt.grid(b=True)

#save to png file
plt.savefig('output_data/Latitude_vs_Temperature.png')

#show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#build scatter plot
x_values2 = lat
y_values2 = humidity
plt.scatter(x_values2,y_values2)

#graph properties
plt.title('City Latitude vs. Humidity')
plt.ylabel('Humidity %')
plt.xlabel('Latitude')
#plt.grid(b=True)

#save to png file
plt.savefig('output_data/Latitude_vs_Humidity.png')

#show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#build scatter plot
x_values3 = lat
y_values3 = cloudiness
plt.scatter(x_values3,y_values3)

#graph properties
plt.title('City Latitude vs. Cloudiness')
plt.ylabel('Cloudiness %')
plt.xlabel('Latitude')
#plt.grid(b=True)

#save to png file
plt.savefig('output_data/Latitude_vs_Cloudiness.png')

#show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#build scatter plot
x_values4 = lat
y_values4 = wind_speed
plt.scatter(x_values4,y_values4)

#graph properties
plt.title('City Latitude vs. Wind Speed')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
#plt.grid(b=True)

#save to png file
plt.savefig('output_data/Latitude_vs_Wind_Speed.png')

#show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Create Northern Hemisphere DataFrame

nh_df = clean_city_df[clean_city_df['Lat'] >= 0].copy()
nh_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  367.000000  367.000000  367.000000  367.000000  367.000000  367.000000
# mean    38.834489   19.457818   35.907684   76.697548   54.299728    7.734905
# std     20.038818   88.624062   34.268684   16.460868   39.009633    6.446208
# min      0.849200 -179.166700  -55.010000   30.000000    0.000000    0.270000
# 25%     21.443950  -62.403150   15.900000   69.000000   13.000000    2.910000
# 50%     39.888500   28.880000   39.200000   81.000000   66.000000    6.330000
# 75%     54.748650   98.242950   64.400000   88.000000   90.000000   10.230000
# max     78.218600  179.316700   86.000000  100.000000  100.000000   32.590000
#
#                Date
# count  3.670000e+02
# mean   1.611445e+09
# std    6.851690e+01
# min    1.611444e+09
# 25%    1.611445e+09
# 50%    1.611445e+09
# 75%    1.611445e+09
# max    1.611445e+09

# %%
#Chart Inputs
nlat = nh_df['Lat']
nlng = nh_df['Lng']
nmax_temp = nh_df['Max Temp']
nhumidity = nh_df['Humidity']
ncloudiness = nh_df['Cloudiness']
nwind_speed = nh_df['Wind Speed']

# %%
#Create Southern Hemisphere DataFrame

sh_df = clean_city_df[clean_city_df['Lat'] < 0].copy()
sh_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  170.000000  170.000000  170.000000  170.000000  170.000000  170.000000
# mean   -20.363127   42.054325   75.137588   73.735294   61.582353    8.226824
# std     13.241196   95.967406    8.006854   15.405196   38.682240    5.714649
# min    -54.800000 -175.200000   50.050000   33.000000    0.000000    0.580000
# 25%    -31.182200  -45.867425   70.090000   66.000000   20.000000    3.655000
# 50%    -20.433900   36.601950   76.980000   76.000000   75.000000    7.260000
# 75%     -8.859250  136.281075   80.600000   85.000000   97.000000   11.265000
# max     -0.130300  173.883300   89.600000  100.000000  100.000000   27.470000
#
#                Date
# count  1.700000e+02
# mean   1.611445e+09
# std    4.047797e+01
# min    1.611445e+09
# 25%    1.611445e+09
# 50%    1.611445e+09
# 75%    1.611445e+09
# max    1.611445e+09

# %%
#Chart Inputs
slat = sh_df['Lat']
slng = sh_df['Lng']
smax_temp = sh_df['Max Temp']
shumidity = sh_df['Humidity']
scloudiness = sh_df['Cloudiness']
swind_speed = sh_df['Wind Speed']

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Set up correlation formula
correlation = st.pearsonr(nlat, nmax_temp)

# Chart Inputs
nx_values1 = nlat
ny_values1 = nmax_temp

# Set up Regression formulas
(slope, intercept, rvalue,pvalue,stderr) = linregress(nx_values1,ny_values1)
regress_values = nx_values1 * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Setu up scatter and regression chart
plt.scatter(nx_values1,ny_values1)
plt.plot (nx_values1,regress_values,"r-")

#Format Chart
plt.annotate(line_eq,(10,-40), fontsize=15, color = "red")
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')

#print correlationa and r_squared
print(f"The correlation between Latitude and Max Temperature is {round(correlation[0],2)}")
print(f"The r_squared is: {rvalue**2}")

#save to png file
plt.savefig('output_data/NH_Latitude_vs_Temperature_Regression.png')

#show plot
plt.show()
# Out:
# The correlation between Latitude and Max Temperature is -0.84
# The r_squared is: 0.7107814836134061

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Set up correlation formula
correlation = st.pearsonr(slat, smax_temp)

# Chart Inputs
sx_values1 = slat
sy_values1 = smax_temp

# Set up Regression formulas
(slope, intercept, rvalue,pvalue,stderr) = linregress(sx_values1,sy_values1)
regress_values = sx_values1 * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Setu up scatter and regression chart
plt.scatter(sx_values1,sy_values1)
plt.plot (sx_values1,regress_values,"r-")

#Format Chart
plt.annotate(line_eq,(-50,90), fontsize=15, color = "red")
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')

#print correlationa and r_squared
print(f"The correlation between Latitude and Max Temperature is {round(correlation[0],2)}")
print(f"The r_squared is: {rvalue**2}")

#save to png file
plt.savefig('output_data/SH_Latitude_vs_Temperature_Regression.png')

#show plot
plt.show()
# Out:
# The correlation between Latitude and Max Temperature is 0.4
# The r_squared is: 0.16316515356007052

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Set up correlation formula
correlation = st.pearsonr(nlat, nhumidity)

# Chart Inputs
nx_values2 = nlat
ny_values2 = nhumidity

# Set up Regression formulas
(slope, intercept, rvalue,pvalue,stderr) = linregress(nx_values2,ny_values2)
regress_values = nx_values2 * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Setu up scatter and regression chart
plt.scatter(nx_values2,ny_values2)
plt.plot (nx_values2,regress_values,"r-")

#Format Chart
plt.annotate(line_eq,(30,30), fontsize=15, color = "red")
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')

#print correlationa and r_squared
print(f"The correlation between Latitude and Humidity is {round(correlation[0],2)}")
print(f"The r_squared is: {rvalue**2}")

#save to png file
plt.savefig('output_data/NH_Latitude_vs_Humidity_Regression.png')

#show plot
plt.show()
# Out:
# The correlation between Latitude and Humidity is 0.23
# The r_squared is: 0.05380963013066005

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Set up correlation formula
correlation = st.pearsonr(slat, shumidity)

# Chart Inputs
sx_values2 = slat
sy_values2 = shumidity

# Set up Regression formulas
(slope, intercept, rvalue,pvalue,stderr) = linregress(sx_values2,sy_values2)
regress_values = sx_values2 * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Setu up scatter and regression chart
plt.scatter(sx_values2,sy_values2)
plt.plot (sx_values2,regress_values,"r-")

#Format Chart
plt.annotate(line_eq,(-30,30), fontsize=15, color = "red")
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')

#print correlationa and r_squared
print(f"The correlation between Latitude and Humidity is {round(correlation[0],2)}")
print(f"The r_squared is: {rvalue**2}")

#save to png file
plt.savefig('output_data/SH_Latitude_vs_Humidity_Regression.png')

#show plot
plt.show()
# Out:
# The correlation between Latitude and Humidity is 0.36
# The r_squared is: 0.12933106044163736

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Set up correlation formula
correlation = st.pearsonr(nlat, ncloudiness)

# Chart Inputs
nx_values3 = nlat
ny_values3 = ncloudiness

# Set up Regression formulas
(slope, intercept, rvalue,pvalue,stderr) = linregress(nx_values3,ny_values3)
regress_values = nx_values3 * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Setu up scatter and regression chart
plt.scatter(nx_values3,ny_values3)
plt.plot (nx_values3,regress_values,"r-")

#Format Chart
plt.annotate(line_eq,(30,30), fontsize=15, color = "red")
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')

#print correlationa and r_squared
print(f"The correlation between Latitude and Cloudiness is {round(correlation[0],2)}")
print(f"The r_squared is: {rvalue**2}")

#save to png file
plt.savefig('output_data/NH_Latitude_vs_Cloudiness_Regression.png')

#show plot
plt.show()
# Out:
# The correlation between Latitude and Cloudiness is 0.23
# The r_squared is: 0.05077477633139525

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Set up correlation formula
correlation = st.pearsonr(slat, scloudiness)

# Chart Inputs
sx_values3 = slat
sy_values3 = scloudiness

# Set up Regression formulas
(slope, intercept, rvalue,pvalue,stderr) = linregress(sx_values3,sy_values3)
regress_values = sx_values3 * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Setu up scatter and regression chart
plt.scatter(sx_values3,sy_values3)
plt.plot (sx_values3,regress_values,"r-")

#Format Chart
plt.annotate(line_eq,(-30,30), fontsize=15, color = "red")
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')

#print correlationa and r_squared
print(f"The correlation between Latitude and Cloudiness is {round(correlation[0],2)}")
print(f"The r_squared is: {rvalue**2}")

#save to png file
plt.savefig('output_data/SH_Latitude_vs_Cloudiness_Regression.png')

#show plot
plt.show()
# Out:
# The correlation between Latitude and Cloudiness is 0.31
# The r_squared is: 0.09516374856544464

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Set up correlation formula
correlation = st.pearsonr(nlat, nwind_speed)

# Chart Inputs
nx_values4 = nlat
ny_values4 = nwind_speed

# Set up Regression formulas
(slope, intercept, rvalue,pvalue,stderr) = linregress(nx_values4,ny_values4)
regress_values = nx_values4 * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Setu up scatter and regression chart
plt.scatter(nx_values4,ny_values4)
plt.plot (nx_values4,regress_values,"r-")

#Format Chart
plt.annotate(line_eq,(30,30), fontsize=15, color = "red")
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')

#print correlationa and r_squared
print(f"The correlation between Latitude and Wind Speed is {round(correlation[0],2)}")
print(f"The r_squared is: {rvalue**2}")

#save to png file
plt.savefig('output_data/NH_Latitude_vs_Wind_Speed_Regression.png')

#show plot
plt.show()
# Out:
# The correlation between Latitude and Wind Speed is 0.1
# The r_squared is: 0.009269742619374572

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Set up correlation formula
correlation = st.pearsonr(slat, swind_speed)

# Chart Inputs
sx_values4 = slat
sy_values4 = swind_speed

# Set up Regression formulas
(slope, intercept, rvalue,pvalue,stderr) = linregress(sx_values4,sy_values4)
regress_values = sx_values4 * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Setu up scatter and regression chart
plt.scatter(sx_values4,sy_values4)
plt.plot (sx_values4,regress_values,"r-")

#Format Chart
plt.annotate(line_eq,(-30,25), fontsize=15, color = "red")
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')

#print correlationa and r_squared
print(f"The correlation between Latitude and Wind Speed is {round(correlation[0],2)}")
print(f"The r_squared is: {rvalue**2}")

#save to png file
plt.savefig('output_data/SH_Latitude_vs_Wind_Speed_Regression.png')

#show plot
plt.show()
# Out:
# The correlation between Latitude and Wind Speed is -0.39
# The r_squared is: 0.15263953651058146
